# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
# Importing data
# Column names: Time (s), Temperature (C),Temperature Error (C), DAC Voltage (%)

part1_max = np.loadtxt('data/4.1-max_temp.csv', delimiter=',', skiprows=1)
part1_min = np.loadtxt('data/4.1-min_temp.csv', delimiter=',', skiprows=1)

part2_band = np.loadtxt('data/4.2-modifying_band.csv', delimiter=',', skiprows=1)
part2_osc1 = np.loadtxt('data/4.2-oscillation-1.csv', delimiter=',', skiprows=1)
part2_osc2 = np.loadtxt('data/4.2-oscillation-2.csv', delimiter=',', skiprows=1)

part3_neg10 = np.loadtxt('data/4.3-neg10.csv', delimiter=',', skiprows=1)
part3_zero = np.loadtxt('data/4.3-0.csv', delimiter=',', skiprows=1)
part3_ten = np.loadtxt('data/4.3-10.csv', delimiter=',', skiprows=1)
part3_twenty = np.loadtxt('data/4.3-20.csv', delimiter=',', skiprows=1)
part3_thirty = np.loadtxt('data/4.3-30.csv', delimiter=',', skiprows=1)
part3_fourty = np.loadtxt('data/4.3-40.csv', delimiter=',', skiprows=1)
part3_fifty = np.loadtxt('data/4.3-50.csv', delimiter=',', skiprows=1)

part4_neg10 = np.loadtxt('data/4.4-neg10.csv', delimiter=',', skiprows=1)
part4_zero = np.loadtxt('data/4.4-0.csv', delimiter=',', skiprows=1)
part4_ten = np.loadtxt('data/4.4-10.csv', delimiter=',', skiprows=1)
part4_twenty = np.loadtxt('data/4.4-20.csv', delimiter=',', skiprows=1)
part4_thirty = np.loadtxt('data/4.4-30.csv', delimiter=',', skiprows=1)
part4_fourty = np.loadtxt('data/4.4-40.csv', delimiter=',', skiprows=1)
part4_fifty = np.loadtxt('data/4.4-50.csv', delimiter=',', skiprows=1)

part3_neg102 = np.loadtxt('data/4.3-neg10-2.4.csv', delimiter=',', skiprows=1)
part3_zero2 = np.loadtxt('data/4.3-0-2.4.csv', delimiter=',', skiprows=1)
part3_ten2 = np.loadtxt('data/4.3-10-2.4.csv', delimiter=',', skiprows=1)
part3_twenty2 = np.loadtxt('data/4.3-20-2.4.csv', delimiter=',', skiprows=1)
part3_thirty2 = np.loadtxt('data/4.3-30-2.4.csv', delimiter=',', skiprows=1)
part3_fourty2 = np.loadtxt('data/4.3-40-2.4.csv', delimiter=',', skiprows=1)
part3_fifty2 = np.loadtxt('data/4.3-50-2.4.csv', delimiter=',', skiprows=1)

part4_neg102 = np.loadtxt('data/4.4-neg10-2.4.csv', delimiter=',', skiprows=1)
part4_zero2 = np.loadtxt('data/4.4-0-2.4.csv', delimiter=',', skiprows=2)
part4_ten2 = np.loadtxt('data/4.4-10-2.4.csv', delimiter=',', skiprows=1)
part4_twenty2 = np.loadtxt('data/4.4-20-2.4.csv', delimiter=',', skiprows=1)
part4_thirty2 = np.loadtxt('data/4.4-30-2.4.csv', delimiter=',', skiprows=1)
part4_fourty2 = np.loadtxt('data/4.4-40-2.4.csv', delimiter=',', skiprows=1)
part4_fifty2 = np.loadtxt('data/4.4-50-2.4.csv', delimiter=',', skiprows=1)

part5_heat1 = np.loadtxt('data/4.5-heat1.csv', delimiter=',', skiprows=1)
part5_heat2 = np.loadtxt('data/4.5-heat2.csv', delimiter=',', skiprows=1)
part5_heat3 = np.loadtxt('data/4.5-heat3.csv', delimiter=',', skiprows=1)
part5_cool1 = np.loadtxt('data/4.5-cold1.csv', delimiter=',', skiprows=1)
part5_cool2 = np.loadtxt('data/4.5-cold2.csv', delimiter=',', skiprows=1)
part5_cool3 = np.loadtxt('data/4.5-cold3.csv', delimiter=',', skiprows=1)

# %%
# INSERT PART 1

# %%
# INSERT PART 2

# %%
# PART 3
#print(part3_neg10[:,3])

# %%
plt.figure(figsize=(12,8))
plt.plot(part3_neg10[:,1]) 
plt.plot(part3_zero[:,1]) 
plt.plot(part3_ten[:,1]) 
plt.plot(part3_twenty[:,1]) 
plt.plot(part3_thirty[:,1]) 
plt.plot(part3_fourty[:,1])
plt.plot(part3_fifty[:,1])
plt.xlabel("Time (s)", size=15)
plt.ylabel("Temperature ($\circ$C)", size=15)
plt.title("Temperature vs. Time (proportional control)", size=17)
plt.xlim(0,250)
plt.savefig("part-3-temp.png", format="png", dpi=1200)
plt.show()

# %%
fig, axs = plt.subplots(3, figsize=(12, 10), sharex=True, sharey=False)
axs[0].plot(part3_ten[25:,1], label=r"Band width = $4.8^\circ C$") 
axs[0].plot(part3_ten2[64:,1], label=r"Band width = $2.4^\circ C$") 
axs[0].set_ylim(5,15)
axs[0].set_title('(a)', size=15)
axs[1].plot(part3_twenty[29:,1]) 
axs[1].plot(part3_twenty2[70:,1]) 
axs[1].set_ylim(15,25)
axs[1].set_title('(b)', size=15)
axs[2].plot(part3_thirty[35:,1]) 
axs[2].plot(part3_thirty2[92:,1]) 
axs[2].set_ylim(25,35)
axs[2].set_title('(c)', size=15)
plt.xlim(0,300)
fig.text(0.074, 0.5, r'Temperature $^\circ C$', va='center', rotation='vertical', size=15)
axs[-1].set_xlabel('Time (s)', size=15)
fig.legend(loc='lower center', ncol=2, fontsize=15) # add common legend
fig.suptitle('Band width impact on Temperature vs Time relationship for Proportional Control', size=18)
plt.savefig("part-3-main.png", format="png", dpi=1200)
plt.show()

# %%
proportional_control_error_big = np.array([np.abs(part3_ten[-1:,1]-10), np.abs(part3_twenty[-1:,1]-20), np.abs(part3_thirty[-1:,1]-30)])
proportional_control_error_small = np.array([np.abs(part3_ten2[-1:,1]-10), np.abs(part3_twenty2[-1:,1]-20), np.abs(part3_thirty2[-1:,1]-30)])

# %%
print(proportional_control_error_big)
print()
print(proportional_control_error_small)
print()
print((proportional_control_error_small+integral_control_error_big)/2)
# Out:
# [[0.544]
#  [0.123]
#  [0.237]]
#
# [[0.241]
#  [0.021]
#  [0.135]]
#
# [[0.3925]
#  [0.072 ]
#  [0.186 ]]

# %%
# PART 4

# %%
plt.figure(figsize=(12,8))
plt.plot(part3_neg10[:,1]) 
plt.plot(part3_zero[:,1]) 
plt.plot(part3_ten[:,1]) 
plt.plot(part3_twenty[:,1]) 
plt.plot(part3_thirty[:,1]) 
plt.plot(part3_fourty[:,1])
plt.plot(part3_fifty[:,1])
plt.xlabel("Time (s)", size=15)
plt.ylabel("Temperature ($\circ$C)", size=15)
plt.title("Temperature vs. Time (proportional integral control)", size=17)
plt.xlim(0,250)
plt.savefig("part-4-temp.png", format="png", dpi=1200)
plt.show()

# %%
fig, axs = plt.subplots(3, figsize=(12, 10), sharex=True, sharey=False)
axs[0].plot(part4_ten[30:,1], label=r"Band width = $4.8^\circ C$") 
axs[0].plot(part4_ten2[137:,1], label=r"Band width = $2.4^\circ C$") 
axs[0].set_ylim(5,15)
axs[0].set_title('(a)', size=15)
axs[1].plot(part4_twenty[30:,1]) 
axs[1].plot(part4_twenty2[98:,1]) 
axs[1].set_ylim(15,25)
axs[1].set_title('(b)', size=15)
axs[2].plot(part4_thirty[35:,1]) 
axs[2].plot(part4_thirty2[107:,1]) 
axs[2].set_ylim(25,35)
axs[2].set_title('(c)', size=15)
plt.xlim(0,300)
fig.text(0.074, 0.5, r'Temperature $^\circ C$', va='center', rotation='vertical', size=15)
axs[-1].set_xlabel('Time (s)', size=15)
fig.legend(loc='lower center', ncol=2, fontsize=15) # add common legend
fig.suptitle('Band width impact on Temperature vs Time relationship for Proportional Integral Control', size=18)
plt.savefig("part-4-main.png", format="png", dpi=1200)
plt.show()

# %%
integral_control_error_big = np.array([np.abs(part4_ten[-1:,1]-10), np.abs(part4_twenty[-1:,1]-20), np.abs(part4_thirty[-1:,1]-30)])
integral_control_error_small = np.array([np.abs(part4_ten2[-1:,1]-10), np.abs(part4_twenty2[-1:,1]-20), np.abs(part4_thirty2[-1:,1]-30)])

# %%
print(integral_control_error_big)
print()
print(integral_control_error_small)
print()
print((integral_control_error_small+integral_control_error_big)/2)
# Out:
# [[0.029]
#  [0.021]
#  [0.   ]]
#
# [[0.005]
#  [0.021]
#  [0.   ]]
#
# [[0.017]
#  [0.021]
#  [0.   ]]

# %%
print("Band 4.8 errors")
print("-ten error: ", np.abs(part4_neg10[-1:,1]+10))
print("zero error: ", np.abs(part4_zero[-1:,1]-0))
print("Fourty error: ",np.abs(part4_fourty[-1:,1]-40))
print("Fifty error: ",np.abs(part4_fifty[-1:,1]-50))
# Out:
# Band 4.8 errors
# -ten error:  [0.007]
# zero error:  [0.017]
# Fourty error:  [0.009]
# Fifty error:  [0.021]

# %%
print("Band 2.4 errors")
print("-ten error: ", np.abs(part4_neg102[-1:,1]+10))
print("zero error: ", np.abs(part4_zero2[-1:,1]-0))
print("Fourty error: ",np.abs(part4_fourty2[-1:,1]-40))
print("Fifty error: ",np.abs(part4_fifty2[-1:,1]-50))
# Out:
# Band 2.4 errors
# -ten error:  [0.026]
# zero error:  [0.017]
# Fourty error:  [0.025]
# Fifty error:  [0.021]
